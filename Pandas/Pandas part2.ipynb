# %%
import pandas as pd

# %% [markdown]
# # csv 파일

# %%
data1=pd.read_csv('/Users/baekjiyoon/Desktop/flights.csv')

# %%
data1
# Out:
#         travelCode  userCode                 from                   to  \
# 0                0         0          Recife (PE)   Florianopolis (SC)
# 1                0         0   Florianopolis (SC)          Recife (PE)
# 2                1         0        Brasilia (DF)   Florianopolis (SC)
# 3                1         0   Florianopolis (SC)        Brasilia (DF)
# 4                2         0         Aracaju (SE)        Salvador (BH)
# ...            ...       ...                  ...                  ...
# 271883      135941      1339    Campo Grande (MS)   Florianopolis (SC)
# 271884      135942      1339   Florianopolis (SC)           Natal (RN)
# 271885      135942      1339           Natal (RN)   Florianopolis (SC)
# 271886      135943      1339   Florianopolis (SC)  Rio de Janeiro (RJ)
# 271887      135943      1339  Rio de Janeiro (RJ)   Florianopolis (SC)
#
#         flightType    price  time  distance       agency        date
# ...

# %% [markdown]
# ## header = None

# %%
data2 =pd.read_csv('/Users/baekjiyoon/Desktop/flights.csv',header=None)
# Out:
# /Users/baekjiyoon/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (0,1,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data2 #OMG
# Out:
#                  0         1                    2                    3  \
# 0       travelCode  userCode                 from                   to
# 1                0         0          Recife (PE)   Florianopolis (SC)
# 2                0         0   Florianopolis (SC)          Recife (PE)
# 3                1         0        Brasilia (DF)   Florianopolis (SC)
# 4                1         0   Florianopolis (SC)        Brasilia (DF)
# ...            ...       ...                  ...                  ...
# 271884      135941      1339    Campo Grande (MS)   Florianopolis (SC)
# 271885      135942      1339   Florianopolis (SC)           Natal (RN)
# 271886      135942      1339           Natal (RN)   Florianopolis (SC)
# 271887      135943      1339   Florianopolis (SC)  Rio de Janeiro (RJ)
# 271888      135943      1339  Rio de Janeiro (RJ)   Florianopolis (SC)
#
#                  4        5     6         7            8           9
# ...

# %% [markdown]
# ## index_col

# %%
data3 =pd.read_csv('/Users/baekjiyoon/Desktop/flights.csv',index_col=None)

# %%
data3
# Out:
#         travelCode  userCode                 from                   to  \
# 0                0         0          Recife (PE)   Florianopolis (SC)
# 1                0         0   Florianopolis (SC)          Recife (PE)
# 2                1         0        Brasilia (DF)   Florianopolis (SC)
# 3                1         0   Florianopolis (SC)        Brasilia (DF)
# 4                2         0         Aracaju (SE)        Salvador (BH)
# ...            ...       ...                  ...                  ...
# 271883      135941      1339    Campo Grande (MS)   Florianopolis (SC)
# 271884      135942      1339   Florianopolis (SC)           Natal (RN)
# 271885      135942      1339           Natal (RN)   Florianopolis (SC)
# 271886      135943      1339   Florianopolis (SC)  Rio de Janeiro (RJ)
# 271887      135943      1339  Rio de Janeiro (RJ)   Florianopolis (SC)
#
#         flightType    price  time  distance       agency        date
# ...

# %%
data3 =pd.read_csv('/Users/baekjiyoon/Desktop/flights.csv',index_col='travelCode')

# %%
data3
# Out:
#             userCode                 from                   to  flightType  \
# travelCode
# 0                  0          Recife (PE)   Florianopolis (SC)  firstClass
# 0                  0   Florianopolis (SC)          Recife (PE)  firstClass
# 1                  0        Brasilia (DF)   Florianopolis (SC)  firstClass
# 1                  0   Florianopolis (SC)        Brasilia (DF)  firstClass
# 2                  0         Aracaju (SE)        Salvador (BH)  firstClass
# ...              ...                  ...                  ...         ...
# 135941          1339    Campo Grande (MS)   Florianopolis (SC)  firstClass
# 135942          1339   Florianopolis (SC)           Natal (RN)    economic
# 135942          1339           Natal (RN)   Florianopolis (SC)    economic
# 135943          1339   Florianopolis (SC)  Rio de Janeiro (RJ)    economic
# 135943          1339  Rio de Janeiro (RJ)   Florianopolis (SC)    economic
#
# ...

# %% [markdown]
# # 엑셀 파일

# %%
Data=pd.read_excel('/Users/baekjiyoon/Desktop/datalab.xlsx')

# %%
Data
# Out:
#            url  \
# 0           주제
# 1           범위
# 2           기간
# 3           성별
# 4          연령대
# 5           날짜
# 6   2020-12-07
# 7   2020-12-08
# 8   2020-12-09
# 9   2020-12-10
# 10  2020-12-11
# 11  2020-12-12
# 12  2020-12-13
# 13  2020-12-14
# 14  2020-12-15
# 15  2020-12-16
#
#    http://datalab.naver.com/keyword/trendResult.naver?hashKey=N_88e8df1811ca504e20966c68a0bd5ff2
# 0                                                  통검
# 1                                                  합계
# 2                        일간 : 2020-12-07 ~ 2020-12-16
# 3                                           전체(여성,남성)
# 4                                                  전체
# 5                                                 롱패딩
# 6                                            31.53698
# 7                                            35.33594
# 8                                            33.81278
# 9                                            29.15854
# ...

# %%
Data=pd.read_excel('/Users/baekjiyoon/Desktop/datalab.xlsx',header=None)

# %%
Data
# Out:
#              0                                                  1
# 0          url  http://datalab.naver.com/keyword/trendResult.n...
# 1           주제                                                 통검
# 2           범위                                                 합계
# 3           기간                       일간 : 2020-12-07 ~ 2020-12-16
# 4           성별                                          전체(여성,남성)
# 5          연령대                                                 전체
# 6           날짜                                                롱패딩
# 7   2020-12-07                                           31.53698
# 8   2020-12-08                                           35.33594
# 9   2020-12-09                                           33.81278
# 10  2020-12-10                                           29.15854
# 11  2020-12-11                                            23.6981
# 12  2020-12-12                                           26.28032
# ...

# %%
Data=Data[6:]

# %%
Data.rename(columns={0:'날짜',1:'검색상대비율'})
# Out:
#             날짜    검색상대비율
# 11  2020-12-11   23.6981
# 12  2020-12-12  26.28032
# 13  2020-12-13  39.14382
# 14  2020-12-14  80.70475
# 15  2020-12-15     100.0
# 16  2020-12-16   61.4928

# %% [markdown]
# # json 파일로 저장

# %%
Data2={"name":["Jenny","Jennifer","Jenn"],
       "job":["Rapper","billionaire","millionaire"],
      }

# %%
df=pd.DataFrame(Data2)

# %%
df
# Out:
#        name          job
# 0     Jenny       Rapper
# 1  Jennifer  billionaire
# 2      Jenn  millionaire

# %%
df.set_index('name',inplace=True)

# %%
df
# Out:
#                   job
# name
# Jenny          Rapper
# Jennifer  billionaire
# Jenn      millionaire

# %%
df.to_json('/Users/baekjiyoon/Desktop/jsonn.json')

# %% [markdown]
# # 엑셀 파일로 저장

# %%
df.to_excel('/Users/baekjiyoon/Desktop/excell.xlsx')

# %% [markdown]
# # 여러 개의 데이터프레임을 하나의 Excel 파일로 저장

# %%
Data3={"name":["Victoria","Torie","Vic"],
       "Nationality":["South Korea","UK","US"],
      }

# %%
df2=pd.DataFrame(Data3)

# %%
df2
# Out:
#        name  Nationality
# 0  Victoria  South Korea
# 1     Torie           UK
# 2       Vic           US

# %%
df2.set_index('name',inplace=True)

# %%
df2
# Out:
#           Nationality
# name
# Victoria  South Korea
# Torie              UK
# Vic                US

# %%
writer=pd.ExcelWriter("/Users/baekjiyoon/Desktop/writer.xlsx")

# %%
df.to_excel(writer,sheet_name="sheet1")

# %%
df2.to_excel(writer,sheet_name="sheet2")

# %%
writer.save()
